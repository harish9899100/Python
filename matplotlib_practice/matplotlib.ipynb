# %%
from numpy import random      # how to work random value 
a = random.randint(100)
print(a)
# Out:
# 6

# %%
b = random.rand(3)
print(b)
# Out:
# [0.37125124 0.10639926 0.2930818 ]

# %%
b = random.rand() # random floating value
print(b)
# Out:
# 0.24838074739000038

# %%
c = random.randint(100, size = 5)
print(c)
# Out:
# [18 27 97 75 67]

# %%
d = random.randint(100, size = (3,4))
print(d)
# Out:
# [[19  8  5 59]
#  [ 1 53 96 23]
#  [70 93  2 62]]

# %%
e = random.choice([3,6,7,1])
print(e)
# Out:
# 7

# %%
f = random.choice([2,3,4,5], size = (3,4))
print(f)
# Out:
# [[2 3 4 3]
#  [3 3 2 3]
#  [2 3 5 4]]

# %%
from numpy import random
a = random.choice([2,4], p = [0.4, 0.6], size = (2, 3))
print(a)
# Out:
# [[2 2 4]
#  [2 4 2]]

# %%
from numpy import random
import numpy as np
arr = np.array([1,2,3,4])
random.shuffle(arr)
print(arr)
# Out:
# [4 2 3 1]

# %%
from numpy import random
import numpy as np
arr = np.array([1,2,3])
print(random.permutation(arr))
# Out:
# [3 2 1]

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 KB 5.8 MB/s eta 0:00:003.1 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 3.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.3 MB/s eta 0:00:00m eta 0:00:010:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 KB 7.5 MB/s eta 0:00:009.4 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 6.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/home/harish/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot([0, 1, 2,3,4,5])

plt.show()

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.6

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([5, 18])
ypoints = np.array([50, 500])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot([1,2,9,4,5])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([2, 20])
ypoints = np.array([10, 100])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot([1,2,3,4,5,6,7])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([1,3])
ypoints = np.array([1, 10])
plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
plt.plot(xpoints, ypoints, 'o:b')
plt.show()

# %%
#  Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10):
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([1,2,6,8])
ypoints = np.array([3,8,1,10])
plt.plot(xpoints, ypoints,'o-.g', ms = 20)
plt.show()

# %%
x = np.array([3,4,10])
y = np.array([5,2,7])
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as ap
y = np.array([2,4,1,6,10])
plt.plot(y,'o:r')
plt.show()

# %%
xpoints = np.array([2,6,1,8,5])
ypoints = np.array([1,5,2,7,3])
plt.plot(xpoints, ypoints,'o--r')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot([2,8,6])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
arr1 = np.array([2,3,4,5])
arr2 = np.array([3,4,5,6])
plt.plot(arr1, arr2, 'o-m', ms = 15, mec = 'g')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot([8,3,4,5,6])
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([5,2,7,4])
ypoints = np.array([2,3,7,1])
plt.plot(xpoints, ypoints, '*-.c', ms = 20, mec = 'r')
plt.show()

# %%
# in this program we are use title() , xlable and ylable 
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([6,2,9,4])
ypoints = np.array([3,4,6,8])
plt.plot(xpoints, ypoints, 'P-.g', ms = '20', mec = 'r', mfc = 'b')
plt.title("practice on notebook")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
# in this program we draw line and we can set the linewidth and color
a = np.array([2,6,4,8])
b = np.array([3,2,5,8])
plt.plot(a, b,c = 'hotpink', lw = '5')
plt.grid(color = 'green', linestyle = '-.', linewidth = '0.8' )
plt.show()

# %%
a = np.array([0,1,2,3])
b = np.array([5,7,2,8])

plt.subplot(1,3,1)
plt.plot(a, b)
plt.title("practice1")

a = np.array([0,1,2,3])
b = np.array([2,5,6,8])

plt.subplot(2,2,3)
plt.plot(a, b)
plt.title("practice2")

a = np.array([0,1,2,3])
b = np.array([1,4,6,3])

plt.subplot(3,1,2)
plt.plot(a, b)
plt.title("practice3")

a = np.array([0,1,2,3])
b = np.array([5,9,2,7])

plt.subplot(2,3,3)
plt.plot(a, b)
plt.title("practice4")

plt.suptitle("practice")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
arr1 = np.array([2,4,3,6])
arr2 = np.array([4,2,6,4])
plt.plot(arr1, arr2, '*--g', ms = '20', mec='r', mfc='c')
plt.title('another practice')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(color = 'b', lw='1', ls='-')
plt.show()

# %%
arr1 = np.array([5,8,9,3])
arr2 = np.array([3,5,7,9])
color = np.array(["black", "orange", "blue", "black"])
sizes = np.array([200, 200, 500, 1000])
plt.scatter(arr1, arr2, c = color, s = sizes, alpha = 0.4)

arr1 = np.array([5,3,7,9])
arr2 = np.array([2,5,8,4])
plt.scatter(arr1, arr2, c = "blue")

arr1 = np.array([2,7,3,9])
arr2 = np.array([5,2,7,9])
plt.scatter(arr1, arr2, c = "red", s = sizes)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
a = np.random.randint(100, size=(100))
b = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(a, b, c=colors, s=sizes)
plt.colorbar()
plt.show()

# %%
a = np.array(['a', 'b', 'c', 'd'])
b = np.array([3,5,7,4])
colors = np.array(["blue", "c", "lightgreen", "hotpink"])
plt.bar(a,b, color=colors, width=0.2)
plt.show()

# %%
a = np.array(['Apple', 'Banana', 'Mango', 'Orange'])
b = np.array([20,23,40,15])
plt.barh(a,b)
plt.grid(c = 'b')
plt.show()

# %%
a = np.random.normal(123,15,267)
plt.hist(a)
plt.show()

# %%
a = np.array([23,34,45,55])
mylabel = ["Apple", "Mango", "Banana", "Orange"]
myexplode = [0.3,0,0,0]
mycolors = ['b', 'g', 'c', 'r']
plt.pie(a, labels=mylabel, explode = myexplod, colors = mycolors)
plt.legend(title = "Fruits:")
plt.show()

# %%
a = np.array([4,7,2,9])
mylable = ["hello", "hey", "bye", "jye"]
myexplods = [0,0,0.8,0]
mycolors = ["g", "r", "b", "hotpink"]
plt.pie(a, labels=mylable,explode = myexplods, colors = mycolors)
plt.legend(title= "practice::")
plt.show()
